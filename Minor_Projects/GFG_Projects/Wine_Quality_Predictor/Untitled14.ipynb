# %% [markdown]
# # Wine Quality Prediction

# %% [markdown]
# ### Import the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Load the dataset

# %%
dataset = pd.read_csv('winequality-red.csv')

# %%
X = dataset.iloc[:,:-1].values

# %%
dataset['goodquality'] = [1 if x >= 7 else 0 for x in dataset['quality']]# Separate feature variables and target variable
y = dataset['goodquality']
dataset = dataset.drop(['goodquality','quality'],axis=1)

# %% [markdown]
# # Splitting the dataset into training and testing set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)
print(X_train)
# Out:
# [[ 9.9   0.54  0.45 ...  3.39  0.62  9.4 ]
#  [10.8   0.26  0.45 ...  3.13  0.54  9.6 ]
#  [ 9.9   0.35  0.55 ...  3.26  0.79 10.6 ]
#  ...
#  [ 7.9   0.57  0.31 ...  3.29  0.69  9.5 ]
#  [13.    0.47  0.49 ...  3.3   0.68 12.7 ]
#  [ 9.8   0.98  0.32 ...  3.25  0.48  9.4 ]]

# %%
print(y_train)
# Out:
# 642     0
# 679     0
# 473     0
# 390     1
# 1096    0
#        ..
# 763     0
# 835     0
# 1216    0
# 559     0
# 684     0
# Name: goodquality, Length: 1279, dtype: int64

# %% [markdown]
# ### HeatMap

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Train the model on SVM Classifier

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='linear',random_state=0)
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ### Predict results

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[290   0]
#  [ 30   0]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.90625
